# %%
import onnx

model = onnx.load("model_repository/densenet_onnx/1/model.onnx")
print(onnx.helper.printable_graph(model.graph))
# Out:
# graph densenet121 (
#   %data_0[FLOAT, 1x3x224x224]
# ) optional inputs with matching initializers (
#   %conv1_w_0[FLOAT, 64x3x7x7]
#   %conv1/bn_scale_0[FLOAT, 64]
#   %conv1/bn_bias_0[FLOAT, 64]
#   %conv1/bn_mean_0[FLOAT, 64]
#   %conv1/bn_var_0[FLOAT, 64]
#   %conv1/bn_w_0[FLOAT, 64]
#   %conv1/bn_b_0[FLOAT, 64]
#   %conv2_1/x1/bn_scale_0[FLOAT, 64]
#   %conv2_1/x1/bn_bias_0[FLOAT, 64]
#   %conv2_1/x1/bn_mean_0[FLOAT, 64]
#   %conv2_1/x1/bn_var_0[FLOAT, 64]
#   %conv2_1/x1/bn_w_0[FLOAT, 64]
#   %conv2_1/x1/bn_b_0[FLOAT, 64]
#   %conv2_1/x1_w_0[FLOAT, 128x64x1x1]
#   %conv2_1/x2/bn_scale_0[FLOAT, 128]
#   %conv2_1/x2/bn_bias_0[FLOAT, 128]
#   %conv2_1/x2/bn_mean_0[FLOAT, 128]
#   %conv2_1/x2/bn_var_0[FLOAT, 128]
#   %conv2_1/x2/bn_w_0[FLOAT, 128]
#   %conv2_1/x2/bn_b_0[FLOAT, 128]
#   %conv2_1/x2_w_0[FLOAT, 32x128x3x3]
#   %conv2_2/x1/bn_scale_0[FLOAT, 96]
#   %conv2_2/x1/bn_bias_0[FLOAT, 96]
#   %conv2_2/x1/bn_mean_0[FLOAT, 96]
#   %conv2_2/x1/bn_var_0[FLOAT, 96]
# ...
